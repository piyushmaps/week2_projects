# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#importing warnings
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("space_server.csv")

# %%
df.head(10)
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
# 5  1.237650e+18  183.847174  0.173694  19.43133  18.46779  18.16451  18.01475
# 6  1.237650e+18  183.864379  0.019201  19.38322  17.88995  17.10537  16.66393
# 7  1.237650e+18  183.900081  0.187473  18.97993  17.84496  17.38022  17.20673
# 8  1.237650e+18  183.924588  0.097246  17.90616  16.97172  16.67541  16.53776
# 9  1.237650e+18  183.973498  0.081626  18.67249  17.71375  17.49362  17.28284
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# ...

# %%
df.tail(10)
# Out:
#              objid          ra        dec         u         g         r  \
# 9990  1.237650e+18  131.115570  51.447136  18.17880  16.71989  16.04004
# 9991  1.237650e+18  131.113284  51.490710  18.58806  16.61418  15.62407
# 9992  1.237650e+18  131.202820  51.499011  19.02614  18.13936  17.82697
# 9993  1.237650e+18  131.398915  51.533706  17.79613  16.02621  15.15955
# 9994  1.237650e+18  131.175791  51.679675  19.52000  18.46195  18.11317
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# 9990  15.66338  15.38130  1345    301       3    160  5.033570e+17  GALAXY
# ...

# %%
df.dtypes
# Out:
# objid        float64
# ra           float64
# dec          float64
# u            float64
# g            float64
# r            float64
# i            float64
# z            float64
# run            int64
# rerun          int64
# camcol         int64
# field          int64
# specobjid    float64
# class         object
# redshift     float64
# plate          int64
# mjd            int64
# fiberid        int64
# dtype: object

# %%
#checking different unique values of the class columns
df["class"].unique()
# Out:
# array(['STAR', 'GALAXY', 'QSO'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["class"]=LE.fit_transform(df["class"])

# %%
df.dtypes
# Out:
# objid        float64
# ra           float64
# dec          float64
# u            float64
# g            float64
# r            float64
# i            float64
# z            float64
# run            int64
# rerun          int64
# camcol         int64
# field          int64
# specobjid    float64
# class          int32
# redshift     float64
# plate          int64
# mjd            int64
# fiberid        int64
# dtype: object

# %%
df.describe()
# Out:
#               objid            ra           dec             u             g  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000  10000.000000
# mean   1.237650e+18    175.529987     14.836148     18.619355     17.371931
# std    1.577039e+05     47.783439     25.212207      0.828656      0.945457
# min    1.237650e+18      8.235100     -5.382632     12.988970     12.799550
# 25%    1.237650e+18    157.370946     -0.539035     18.178035     16.815100
# 50%    1.237650e+18    180.394514      0.404166     18.853095     17.495135
# 75%    1.237650e+18    201.547279     35.649397     19.259232     18.010145
# max    1.237650e+18    260.884382     68.542265     19.599900     19.918970
#
#                   r             i             z           run    rerun  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.0
# mean      16.840963     16.583579     16.422833    981.034800    301.0
# ...

# %% [markdown]
# observation
#
#
# -->dec,fiel,specobjid,redshift,plate,fiberid the difference between the max and 75 percentile is quite wide hence outliers are present in this field
#
# -->dec,run,redshift,plate,mjd in these columns mean is quite larger  than median and hence data is right skewed
#
# -->camcol,specobjid  these columns median is substantially higher  than mean and hence data is left skewed

# %% [markdown]
# # Exploring Data Variables

# %%
#printing the target columns and their unique values
df["class"].value_counts()
#0=galaxy ,star=2,osr=1
# Out:
# 0    4998
# 2    4152
# 1     850
# Name: class, dtype: int64

# %%
#checking unique values of all dataset
df.nunique()
# Out:
# objid            1
# ra           10000
# dec          10000
# u             9730
# g             9817
# r             9852
# i             9890
# z             9896
# run             23
# rerun            1
# camcol           6
# field          703
# specobjid     6349
# class            3
# redshift      9637
# plate          487
# mjd            355
# fiberid        892
# dtype: int64

# %% [markdown]
# # CHecking the correlation

# %%
df_corr=df.corr()
df_corr=df_corr.drop("rerun")
df_corr
# Out:
#                   objid            ra           dec             u  \
# objid      1.000000e+00  2.524419e-14 -1.937483e-15  5.581214e-14
# ra         2.524419e-14  1.000000e+00  3.596046e-03  3.123756e-02
# dec       -1.937483e-15  3.596046e-03  1.000000e+00  3.527932e-02
# u          5.581214e-14  3.123756e-02  3.527932e-02  1.000000e+00
# g          1.001149e-13  4.390863e-02  6.187471e-02  8.492320e-01
# r          2.995673e-14  4.710290e-02  6.340395e-02  6.923790e-01
# i          2.212198e-14  4.573107e-02  5.829189e-02  6.026302e-01
# z         -4.107700e-14  4.294957e-02  5.687030e-02  5.514828e-01
# run       -1.553011e-14 -9.274056e-02  7.783849e-01  3.822910e-02
# camcol     1.921887e-15 -6.293831e-03  1.146139e-01  9.944672e-03
# field      5.938881e-16  5.946996e-01 -1.314714e-01  8.547880e-03
# specobjid -1.829075e-15 -9.532711e-02  8.834533e-02 -1.294293e-01
# class     -3.355500e-15 -4.321896e-02 -5.891815e-02 -2.690437e-01
# ...

# %%
#plotting heatmap
plt.figure(figsize=(16,10))
sns.heatmap(df_corr,annot=True)
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df_corr,annot=True,fmt=".0%",cmap="Accent")
plt.show()

# %% [markdown]
# observation
#
# -->specobjid,plate,mjd are highest correlated columns with the target variable
#
# -->whereas u and g are negatively correlated with the class column
#
# -->u,g,i,r,z are highly correlated to each other
#
# -->specobjid,mjd,plate are highly correlated to each other
#
# conclusion- we can merge several column which are highly correlated to each other using PCA techniques

# %%
plt.figure(figsize=(10,8))
comparison=df.drop("class",axis=1).corrwith(df["class"])
comparison.plot(kind="bar",grid=True,color="yellow")
plt.xticks(rotation=20)
plt.title("correlation with target Variable")
# Out:
# Text(0.5, 1.0, 'correlation with target Variable')

# %% [markdown]
# # Univariate Analysis¶

# %%
df.head(3)
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
#
#           z  run  rerun  camcol  field     specobjid  class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18      2 -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17      2 -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17      0  0.123111    287
#
#      mjd  fiberid
# 0  54922      491
# 1  51615      541
# 2  52023      513

# %%
#checking the count of the class
sns.countplot(df["class"])
plt.title("Class uniqu values")
plt.xlabel("0= Galaxy,2=star,1=osr")
# Out:
# Text(0.5, 0, '0= Galaxy,2=star,1=osr')

# %% [markdown]
# observation
#
# -->Galaxies are most prominent and osr are the least

# %%
plt.figure(figsize=(10,8))
sns.countplot(x="camcol",data=df)
plt.title("concol values")
plt.xlabel("camcol values range from 1 to 6")
plt.ylabel("count")
plt.show()
print("\n ",df.camcol.value_counts())
# Out:
#   4    1834
# 5    1827
# 6    1769
# 2    1712
# 3    1560
# 1    1298
# Name: camcol, dtype: int64

# %% [markdown]
# observation
#
# -->hence the  4,5, and 6th camera col is used maximum time

# %%
plt.figure(figsize=(10,8))
sns.countplot(x="run",data=df)
plt.title("")
plt.xlabel("Run values")
plt.ylabel("count")
plt.show()
print("\n ",df.run.value_counts())
# Out:
#   756     3060
# 752     2086
# 1345     915
# 1350     540
# 1140     527
# 745      453
# 1035     396
# 1412     347
# 1302     246
# 1331     245
# 1231     245
# 1334     212
# 1239     197
# 1336     182
# 1404     137
# 1045     112
# 1402      49
# 308       31
# 1411      10
# 1356       4
# 727        4
# 1119       1
# 1332       1
# Name: run, dtype: int64

# %% [markdown]
# observation
#
# -->run which is drift scan of the sdss ,the most frequent run is 756 which is 3060 times and least is 1332 and 1119 run for only 1 time

# %%
col_list={"reddhift hist plot":"redshift", "plate hist plot":"plate","mjd hist plot":"mjd"}
for label_plot,col in col_list.items():
    df[col].hist(bins=5)
    plt.axvline(np.mean(df[col]),linewidth=4,color="red",label=label_plot)
    plt.xlabel(col)
    plt.ylabel("count")
    plt.show()
    print("\n\n")

# %%
df.nunique()
# Out:
# objid            1
# ra           10000
# dec          10000
# u             9730
# g             9817
# r             9852
# i             9890
# z             9896
# run             23
# rerun            1
# camcol           6
# field          703
# specobjid     6349
# class            3
# redshift      9637
# plate          487
# mjd            355
# fiberid        892
# dtype: int64

# %% [markdown]
# # BI-variate analysis

# %%
sns.FacetGrid(df,col="class").map(sns.distplot,"ra")

# %% [markdown]
# #observation
#
# -->the distribution is standard within all the different classes

# %%
plt.figure(figsize=(10,8))
sns.countplot(x="camcol",hue="class",data=df)
plt.title("concol values")
plt.xlabel("camcol values range from 1 to 6")
plt.ylabel("count")
plt.show()
print("\n ",df.camcol.value_counts())
# Out:
#   4    1834
# 5    1827
# 6    1769
# 2    1712
# 3    1560
# 1    1298
# Name: camcol, dtype: int64

# %%
df.nunique()
# Out:
# objid            1
# ra           10000
# dec          10000
# u             9730
# g             9817
# r             9852
# i             9890
# z             9896
# run             23
# rerun            1
# camcol           6
# field          703
# specobjid     6349
# class            3
# redshift      9637
# plate          487
# mjd            355
# fiberid        892
# dtype: int64

# %% [markdown]
# # Multivariate analysis

# %%
plt.figure(figsize=(100,80))
sns.pairplot(df, hue="class", palette="Set2", diag_kind="kde", height=2.5)
plt.show()

# %% [markdown]
# # checking skewness

# %%
df.skew()
# Out:
# objid        1.000150
# ra          -1.227350
# dec          1.191544
# u           -1.219795
# g           -0.536293
# r           -0.021673
# i            0.286442
# z            0.214313
# run          0.412555
# rerun        0.000000
# camcol      -0.100220
# field        0.249795
# specobjid    1.794627
# class        0.169292
# redshift     4.265729
# plate        1.794609
# mjd          1.039610
# fiberid      0.308053
# dtype: float64

# %%
for col in df.columns:
    if df[col].skew()>0.55:
        df[col]=np.sqrt(df[col]) 
    if df[col].skew()<-0.55:
        df[col]=np.cbrt(df[col])

# %%
df.skew()
# Out:
# objid        1.000150
# ra          -2.773755
# dec          0.298224
# u           -1.315798
# g           -0.536293
# r           -0.021673
# i            0.286442
# z            0.214313
# run          0.412555
# rerun        0.000000
# camcol      -0.100220
# field        0.249795
# specobjid    1.093905
# class        0.169292
# redshift     2.268173
# plate        1.093870
# mjd          1.025184
# fiberid      0.308053
# dtype: float64

# %%
#further treating the skewness
col_list=["specobjid","redshift","plate","mjd"]
for col in col_list:
    if df[col].skew()>0.55:
        df[col]=np.log10(df[col])

# %%
df.skew()
# Out:
# objid        1.000150
# ra          -2.773755
# dec          0.298224
# u           -1.315798
# g           -0.536293
# r           -0.021673
# i            0.286442
# z            0.214313
# run          0.412555
# rerun        0.000000
# camcol      -0.100220
# field        0.249795
# specobjid    0.696181
# class        0.169292
# redshift          NaN
# plate        0.696137
# mjd          1.011097
# fiberid      0.308053
# dtype: float64

# %%
df.isnull().sum()
# Out:
# objid           0
# ra              0
# dec          3774
# u               0
# g               0
# r               0
# i               0
# z               0
# run             0
# rerun           0
# camcol          0
# field           0
# specobjid       0
# class           0
# redshift     1919
# plate           0
# mjd             0
# fiberid         0
# dtype: int64

# %%
df
# Out:
#              objid        ra       dec         u         g         r  \
# 0     1.237650e+18  5.682901  0.299488  2.690412  17.04240  15.94699
# 1     1.237650e+18  5.683593  0.367811  2.652522  17.21449  16.67637
# 2     1.237650e+18  5.684437  0.355225  2.686211  18.19169  17.47428
# 3     1.237650e+18  5.686400  0.223407  2.609304  16.60272  16.16116
# 4     1.237650e+18  5.686531  0.320245  2.598730  16.26342  16.43869
# ...            ...       ...       ...       ...       ...       ...
# 9995  1.237650e+18  5.082839  7.179105  2.659843  17.47053  16.91508
# 9996  1.237650e+18  5.082706  7.188278  2.633903  17.43849  17.07692
# 9997  1.237650e+18  5.085884  7.187975  2.657033  17.77784  17.51872
# 9998  1.237650e+18  5.084912  7.193961  2.662907  17.91068  17.53152
# 9999  1.237650e+18  5.087333  7.197590  2.681254  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field  specobjid  class  \
# ...

# %%
#replacing the nan with mean
col_list=["dec","redshift"]
for col in col_list:
    df[col]=df[col].replace(np.nan,df[col].mean())

# %%
#removed all the null value
df.isnull().sum()
# Out:
# objid        0
# ra           0
# dec          0
# u            0
# g            0
# r            0
# i            0
# z            0
# run          0
# rerun        0
# camcol       0
# field        0
# specobjid    0
# class        0
# redshift     0
# plate        0
# mjd          0
# fiberid      0
# dtype: int64

# %%
col_list=["redshift"]
for col in col_list:
    df[col]= df[col].replace([np.inf, -np.inf], np.nan)

# %%
col_list=["redshift"]
for col in col_list:
    df[col]=df[col].replace(np.nan,df[col].mean())

# %% [markdown]
# # Detecting outliers

# %%
#it will show the outliers 
df.plot(kind="box",subplots=True,layout=(4,5),figsize=(16,10))
# Out:
# objid            AxesSubplot(0.125,0.71587;0.133621x0.16413)
# ra            AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# dec            AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# u             AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# g             AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# r               AxesSubplot(0.125,0.518913;0.133621x0.16413)
# i            AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# z             AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# run          AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# rerun        AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# camcol          AxesSubplot(0.125,0.321957;0.133621x0.16413)
# field        AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# specobjid     AxesSubplot(0.44569,0.321957;0.133621x0.16413)
# class        AxesSubplot(0.606034,0.321957;0.133621x0.16413)
# redshift     AxesSubplot(0.766379,0.321957;0.133621x0.16413)
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
x = scaler.fit_transform(df1)

# %%
#using PCA technique to shorten the columns
from sklearn.decomposition import PCA
x=df1.drop(["class",'rerun',"objid"],axis=1)
y=df1["class"]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
x = scaler.fit_transform(x)

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=89,test_size=.20,stratify=y)

# %%
print(x_train.shape,"\n",x_test.shape)
# Out:
# (8000, 15)
#  (2000, 15)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

#importing error metrics
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import GridSearchCV,cross_val_score

# %% [markdown]
# # Finding the best parameters

# %%
#using the gridsearchCV finding the best parameter in logistic regression
parameters={"random_state":range(42,100)}
LG=LogisticRegression()

gcv=GridSearchCV(LG,parameters)
gcv.fit(x,y)
print(gcv.best_params_)

# %%
#best parameters for knn
parameters={"n_neighbors":range(1,30)}
KNN=KNeighborsClassifier()

gcv=GridSearchCV(KNN,parameters)
gcv.fit(x,y)
print(gcv.best_params_)

# %%
LG=LogisticRegression(random_state=42)
KNN=KNeighborsClassifier(n_neighbors=28)
SVC=SVC()
model1=[LG,GaussianNB(),DecisionTreeClassifier(),KNN,SVC]
for mod in model1:
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=89,test_size=.20,stratify=y)
    print("*************",mod,"***************")
    mod.fit(x_train,y_train)
    mod.score(x_train,y_train)
    y_pred=mod.predict(x_test)
    print("Accuracy score of ",mod,"is as follow" )
    print("\n",accuracy_score(y_test,y_pred))
    print("classification report=  ",classification_report(y_test,y_pred))
    print("\n\n")
    print("******************************************")
    print("\n\n")

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier

# %%
model_boost=[RandomForestClassifier(),AdaBoostClassifier(),GradientBoostingClassifier(),BaggingClassifier(),ExtraTreesClassifier()]

for mod in model_boost:
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=89,test_size=.20,stratify=y)
    print("*************",mod,"***************")
    mod.fit(x_train,y_train)
    mod.score(x_train,y_train)
    y_pred=mod.predict(x_test)
    print("Accuracy score of ",mod,"is as follow" )
    print("\n",accuracy_score(y_test,y_pred))
    print("classification report=  ",classification_report(y_test,y_pred))
    print("\n\n")
    print("******************************************")
    print("\n\n")

# %%
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
RFC.score(x_train,y_train)
pred_rfc=RFC.predict(x_test)
print(accuracy_score(y_test,pred_rfc))
print(confusion_matrix(y_test,pred_rfc))
print(classification_report(y_test,pred_rfc))

# %%
gbc=GradientBoostingClassifier(learning_rate=0.1,random_state=42,n_estimators=200)
gbc.fit(x_train,y_train)
gbc.score(x_train,y_train)
pred_gbc=gbc.predict(x_test)
print(accuracy_score(y_test,pred_gbc))
print(confusion_matrix(y_test,pred_gbc))
print(classification_report(y_test,pred_gbc))

# %%
#gradient boost is giving the best score at 98.7 percent
